# %% [markdown]
# # 📝 Exercícios — Aula 01: Fundamentos de Python
#
# **Instruções:**
# - Resolva cada exercício na célula indicada com `# Seu código aqui`
# - Execute a célula de teste logo abaixo para verificar sua resposta
# - Tente resolver **sem olhar** o gabarito antes de tentar!
# - Dificuldade: ⭐ Fácil | ⭐⭐ Médio | ⭐⭐⭐ Desafiador
#
# ---

# %% [markdown]
# ## Bloco 1 — Variáveis e Tipos de Dados

# %% [markdown]
# ### ⭐ Exercício 1 — Apresentação pessoal
# Crie variáveis com seu **nome**, **idade**, **altura** e **cidade**.
# Depois imprima uma frase usando f-string no formato:
#
# `Olá! Meu nome é [nome], tenho [idade] anos, medo [altura]m e moro em [cidade].`

# %%
# Seu código aqui
nome = 
idade = 
altura = 
cidade = 

print(f"")

# %% [markdown]
# ### ⭐ Exercício 2 — Calculadora de IMC
# Dados o peso (kg) e a altura (m), calcule o IMC com a fórmula `IMC = peso / altura²`.
# Imprima o resultado com **2 casas decimais**.

# %%
peso = 72.5
altura = 1.75

# Seu código aqui
imc = 

print(f"IMC: {imc:.2f}")

# %%
# ✅ Teste automático
assert round(imc, 2) == 23.67, f"Esperado 23.67, obteve {round(imc,2)}"
print("✅ Exercício 2 correto!")

# %% [markdown]
# ### ⭐ Exercício 3 — Manipulação de Strings
# Dada a string abaixo, realize as operações pedidas nos comentários.

# %%
frase = "  python para ciência de dados  "

# 1. Remova os espaços do início e fim
frase_limpa = 

# 2. Coloque a primeira letra de cada palavra em maiúsculo
frase_titulo = 

# 3. Conte quantas vezes a letra 'a' aparece na frase_limpa
qtd_a = 

# 4. Substitua 'dados' por 'analytics'
frase_nova = 

print(frase_limpa)
print(frase_titulo)
print(f"Letra 'a' aparece {qtd_a} vezes")
print(frase_nova)

# %% [markdown]
# ---
# ## Bloco 2 — Estruturas Condicionais

# %% [markdown]
# ### ⭐ Exercício 4 — Classificação de IMC
# Usando o IMC calculado no Exercício 2, classifique de acordo com a tabela:
#
# | IMC | Classificação |
# |-----|---------------|
# | < 18.5 | Abaixo do peso |
# | 18.5 – 24.9 | Peso normal |
# | 25.0 – 29.9 | Sobrepeso |
# | ≥ 30.0 | Obesidade |

# %%
# Use o valor imc = 23.67 (do exercício 2) ou defina aqui
imc = 23.67

# Seu código aqui
if :
    classificacao = 
elif :
    classificacao = 

print(f"IMC: {imc} → {classificacao}")

# %% [markdown]
# ### ⭐⭐ Exercício 5 — Calculadora de Desconto
# Crie uma lógica que aplique desconto conforme o valor da compra:
# - Compra < R$100 → sem desconto
# - R$100 a R$299 → 5% de desconto
# - R$300 a R$499 → 10% de desconto
# - R$500 ou mais → 15% de desconto

# %%
valor_compra = 350.0

# Seu código aqui
desconto_pct = 
valor_desconto = 
valor_final = 

print(f"Valor original: R$ {valor_compra:.2f}")
print(f"Desconto ({desconto_pct*100:.0f}%): R$ {valor_desconto:.2f}")
print(f"Valor final:    R$ {valor_final:.2f}")

# %%
# ✅ Teste automático
assert desconto_pct == 0.10, f"Desconto esperado: 10%, obteve: {desconto_pct*100}%"
assert round(valor_final, 2) == 315.00, f"Valor final esperado: 315.00"
print("✅ Exercício 5 correto!")

# %% [markdown]
# ---
# ## Bloco 3 — Estruturas de Repetição

# %% [markdown]
# ### ⭐ Exercício 6 — Tabuada
# Imprima a tabuada do número 7 (de 1 a 10) usando um loop `for`.

# %%
numero = 7

# Seu código aqui
print(f"=== Tabuada do {numero} ===")
for i in range(1, 11):
    # complete aqui
    pass

# %% [markdown]
# ### ⭐⭐ Exercício 7 — Filtrando dados
# Dada a lista de vendas abaixo, use um loop para calcular:
# 1. O total de vendas acima de R$500
# 2. A quantidade de vendas acima de R$500
# 3. A média dessas vendas altas

# %%
vendas = [120, 850, 230, 670, 410, 990, 55, 780, 345, 620]

# Seu código aqui
total_altas = 0
qtd_altas = 0

for venda in vendas:
    # complete aqui
    pass

media_altas = total_altas / qtd_altas if qtd_altas > 0 else 0

print(f"Vendas acima de R$500: {qtd_altas}")
print(f"Total:  R$ {total_altas:.2f}")
print(f"Média:  R$ {media_altas:.2f}")

# %%
# ✅ Teste automático
assert qtd_altas == 5, f"Esperado 5 vendas altas, obteve {qtd_altas}"
assert total_altas == 3910, f"Esperado total 3910, obteve {total_altas}"
print("✅ Exercício 7 correto!")

# %% [markdown]
# ### ⭐⭐ Exercício 8 — List Comprehension
# Reescreva as operações abaixo usando **list comprehension** em uma única linha:

# %%
numeros = list(range(1, 21))   # [1, 2, 3, ..., 20]

# 1. Crie uma lista com o quadrado de todos os números ímpares
quadrados_impares = []  # substitua pelo list comprehension

# 2. Crie uma lista com os números divisíveis por 3 ou por 5
div_3_ou_5 = []  # substitua pelo list comprehension

# 3. Converta cada número para string com prefixo 'item_'
itens = []  # substitua pelo list comprehension

print("Quadrados dos ímpares:", quadrados_impares)
print("Divisíveis por 3 ou 5:", div_3_ou_5)
print("Itens:", itens[:5], "...")

# %% [markdown]
# ---
# ## Bloco 4 — Estruturas de Dados

# %% [markdown]
# ### ⭐⭐ Exercício 9 — Análise de notas com Dicionário
# Complete o código para gerar um relatório de desempenho da turma.

# %%
turma = {
    "Alice":   [9.0, 8.5, 10.0, 9.2],
    "Bruno":   [6.5, 7.0, 6.8, 7.5],
    "Carla":   [5.0, 4.5, 6.0, 5.8],
    "Diego":   [8.0, 9.5, 7.8, 8.9],
    "Emília":  [3.5, 4.0, 5.2, 4.8],
}

# Seu código: calcule a média de cada aluno e classifique
print(f"{'Aluno':<10} {'Média':>6}  {'Situação'}")
print("-" * 35)

aprovados = []
reprovados = []

for aluno, notas in turma.items():
    media = # calcule a média
    situacao = # Aprovado (>=6) ou Reprovado
    
    if media >= 6.0:
        aprovados.append(aluno)
    else:
        reprovados.append(aluno)
    
    print(f"{aluno:<10} {media:>6.2f}  {situacao}")

print("-" * 35)
print(f"Aprovados ({len(aprovados)}):  {', '.join(aprovados)}")
print(f"Reprovados ({len(reprovados)}): {', '.join(reprovados)}")

# %% [markdown]
# ### ⭐⭐⭐ Exercício 10 — Análise de Dataset de Vendas
# Você tem uma lista de dicionários representando vendas. Resolva as questões abaixo.

# %%
vendas = [
    {"produto": "Notebook",  "categoria": "Eletrônicos", "valor": 3500, "regiao": "Norte"},
    {"produto": "Cadeira",   "categoria": "Móveis",      "valor": 850,  "regiao": "Sul"},
    {"produto": "Monitor",   "categoria": "Eletrônicos", "valor": 1200, "regiao": "Sudeste"},
    {"produto": "Mesa",      "categoria": "Móveis",      "valor": 1100, "regiao": "Norte"},
    {"produto": "Teclado",   "categoria": "Eletrônicos", "valor": 320,  "regiao": "Sul"},
    {"produto": "Sofá",      "categoria": "Móveis",      "valor": 2800, "regiao": "Sudeste"},
    {"produto": "Headset",   "categoria": "Eletrônicos", "valor": 450,  "regiao": "Norte"},
    {"produto": "Estante",   "categoria": "Móveis",      "valor": 680,  "regiao": "Sul"},
]

# 1. Qual é o valor total de todas as vendas?
total_geral = 

# 2. Qual é o produto mais caro?
produto_mais_caro = 

# 3. Qual categoria tem maior faturamento total?
faturamento_por_categoria = {}  # {'Eletrônicos': X, 'Móveis': Y}
# Seu código aqui

# 4. Quais produtos custam mais de R$1000? (use list comprehension)
produtos_premium = 

print(f"Total geral: R$ {total_geral:,.2f}")
print(f"Produto mais caro: {produto_mais_caro}")
print(f"Faturamento por categoria: {faturamento_por_categoria}")
print(f"Produtos premium (>R$1000): {produtos_premium}")

# %% [markdown]
# ---
# ## Bloco 5 — Boas Práticas

# %% [markdown]
# ### ⭐⭐⭐ Exercício 11 — Refatoração
# O código abaixo funciona, mas viola várias boas práticas. **Reescreva-o** aplicando: nomes descritivos, funções, DRY e docstrings.

# %%
# ❌ CÓDIGO ORIGINAL (funciona, mas está mal escrito)
d = [1000, 1500, 2000, 800, 3000, 1200]
x = 0
for i in d:
    x = x + i
m = x / len(d)
print("media", m)
t = 0
for i in d:
    if i > m:
        t = t + i
print("total acima media", t)

# %%
# ✅ SEU CÓDIGO REFATORADO AQUI
# Aplique: nomes descritivos, funções com docstrings, type hints

def calcular_media(valores: list) -> float:
    """
    # Complete a docstring
    """
    pass  # implemente aqui


def somar_acima_da_media(valores: list, media: float) -> float:
    """
    # Complete a docstring  
    """
    pass  # implemente aqui


# Use as funções:
salarios_mensais = [1000, 1500, 2000, 800, 3000, 1200]

# Seu código aqui

# %% [markdown]
# ---
# ## 🏆 Desafio Final — Mini Projeto
#
# ### ⭐⭐⭐ Exercício 12 — Sistema de Boletim Escolar
#
# Crie um sistema completo que:
# 1. Armazene dados de alunos com nome, notas e frequência (%)
# 2. Calcule a média de cada aluno
# 3. Considere **reprovado por frequência** se frequência < 75%
# 4. Gere um relatório formatado com todos os dados
# 5. Liste os 3 melhores alunos (por média)

# %%
alunos = [
    {"nome": "Ana Costa",     "notas": [9.0, 8.5, 9.5, 8.8], "frequencia": 92},
    {"nome": "Bruno Lima",    "notas": [7.0, 6.5, 8.0, 7.2], "frequencia": 78},
    {"nome": "Carla Souza",   "notas": [5.5, 6.0, 5.8, 6.2], "frequencia": 70},
    {"nome": "Diego Rocha",   "notas": [8.5, 9.0, 8.8, 9.3], "frequencia": 95},
    {"nome": "Emília Nunes",  "notas": [4.0, 5.0, 4.5, 5.5], "frequencia": 80},
    {"nome": "Felipe Moura",  "notas": [7.5, 7.0, 8.2, 7.8], "frequencia": 68},
]

# SEU CÓDIGO AQUI
# Dica: construa funções auxiliares antes do loop principal

# %% [markdown]
# ---
# ## 📖 Gabarito
#
# > ⚠️ **Tente resolver todos os exercícios antes de consultar!**
# > Execute a célula abaixo para ver as soluções.

# %%
# GABARITO — Exercício 2
peso, altura = 72.5, 1.75
imc = peso / altura ** 2
print(f"Ex.2 IMC: {imc:.2f}")

# GABARITO — Exercício 5
valor_compra = 350.0
if valor_compra < 100: desconto_pct = 0
elif valor_compra < 300: desconto_pct = 0.05
elif valor_compra < 500: desconto_pct = 0.10
else: desconto_pct = 0.15
valor_final = valor_compra * (1 - desconto_pct)
print(f"Ex.5 Valor final: R$ {valor_final:.2f}")

# GABARITO — Exercício 7
vendas_ex7 = [120, 850, 230, 670, 410, 990, 55, 780, 345, 620]
altas = [v for v in vendas_ex7 if v > 500]
print(f"Ex.7 Qtd altas: {len(altas)}, Total: {sum(altas)}, Média: {sum(altas)/len(altas):.2f}")

# GABARITO — Exercício 8
numeros = list(range(1, 21))
quadrados_impares = [n**2 for n in numeros if n % 2 != 0]
div_3_ou_5 = [n for n in numeros if n % 3 == 0 or n % 5 == 0]
itens = [f"item_{n}" for n in numeros]
print(f"Ex.8 Quadrados ímpares: {quadrados_impares}")

# GABARITO — Exercício 10
vendas_ex10 = [
    {"produto": "Notebook",  "categoria": "Eletrônicos", "valor": 3500, "regiao": "Norte"},
    {"produto": "Cadeira",   "categoria": "Móveis",      "valor": 850,  "regiao": "Sul"},
    {"produto": "Monitor",   "categoria": "Eletrônicos", "valor": 1200, "regiao": "Sudeste"},
    {"produto": "Mesa",      "categoria": "Móveis",      "valor": 1100, "regiao": "Norte"},
    {"produto": "Teclado",   "categoria": "Eletrônicos", "valor": 320,  "regiao": "Sul"},
    {"produto": "Sofá",      "categoria": "Móveis",      "valor": 2800, "regiao": "Sudeste"},
    {"produto": "Headset",   "categoria": "Eletrônicos", "valor": 450,  "regiao": "Norte"},
    {"produto": "Estante",   "categoria": "Móveis",      "valor": 680,  "regiao": "Sul"},
]
total_geral = sum(v["valor"] for v in vendas_ex10)
produto_mais_caro = max(vendas_ex10, key=lambda v: v["valor"])["produto"]
fat_cat = {}
for v in vendas_ex10:
    fat_cat[v["categoria"]] = fat_cat.get(v["categoria"], 0) + v["valor"]
produtos_premium = [v["produto"] for v in vendas_ex10 if v["valor"] > 1000]
print(f"Ex.10 Total: R${total_geral:,} | Mais caro: {produto_mais_caro} | Premium: {produtos_premium}")
